# %% [markdown]
# # 文本分析與程式設計Week2-課間練習解答

# %% [markdown]
# ## 課間練習1
# - 想想看，你是怎麼判斷一個文章的大意呢？
# - 想想看特徵詞的定義，你覺得特徵詞等同於文章大意嗎？
# - 看完TF 和 IDF 的內容，你覺決TF 和 IDF 哪個比較接近我們人類思考之中的特徵詞呢？為什麼？
# - 想一想TF 和 IDF 是如何計算的，你覺得和人類判斷語意一樣嗎？為什麼？

# %% [markdown]
# ## 課間練習2
# - 請看以下的新聞，並利用前一堂課學習到的Articut 斷詞方法斷詞，並計算頻率，什麼字詞頻率最高？高頻率的那些字是可以代表那篇新聞的字詞嗎？
#
# （中央社記者葉冠吟台北27日電）入圍坎城影展、改編自村上春樹短篇小說的日本電影Drive My Car，由西島秀俊、岡田將生主演，台灣演員袁子芸也參演，更透露西島秀俊本人相當親切，還有許多暖男舉動。袁子芸曾參演戲劇「泡沫之夏」、「未來媽媽」，Drive My Car是她的首部日本電影，飾演一名母語是中英雙語的女演員，在角色背景設定上與她自身有許多相似之處。袁子芸表示，開拍第一天自己很緊張，而且第一場戲就與岡田將生有近距離接觸。不過當時午餐放飯時間延遲，拍戲時大家都有點餓，沒想到在最安靜的瞬間，岡田將生的肚子竟然咕嚕叫了一聲。袁子芸回憶，當下兩人都很專業的繼續演出，等導演一喊卡之後，才忍不住大笑出來，連岡田將生都笑著表示不好意思。不過也因為這個意外插曲，沖淡第一天拍攝的緊張和陌生感，瞬間拉近演員之間的距離。關於男主角西島秀俊，袁子芸看過許多他的作品，原以為他是比較有距離感的大明星，沒想到西島秀俊在讀本過程就相當親切，還有許多暖男舉動。袁子芸分享，有天海外演員殺青後，相約要去慶祝，但因西島秀俊隔天一早還有拍攝，無法同行，他便私下交代製片想請大家吃飯，麻煩製片先代為招待。近日電影傳出入圍坎城影展好消息，袁子芸也相當開心，她表示劇組群組簡直要暴動。雖然她很希望能和劇組一起慶祝，卻因大家都分散不同地方，又正值疫情期間，只能透過通訊軟體互相道賀，期待Drive My Car 能在坎城影展奪下好成績。由柏林影展銀熊獎得主、導演濱口龍介執導的Drive My Car，描述一名想尋找亡妻生前外遇對象的舞台劇演員，藉由與沉默寡言女司機的對話，描繪出各自的故事與情感，電影8月20日將於日本上映。（編輯：張雅淨）1100627
#
# The news is from https://www.cna.com.tw/news/amov/202106270091.aspx

# %%
from ArticutAPI import Articut
from pprint import pprint

newsinputSTR = """
（中央社記者葉冠吟台北27日電）入圍坎城影展、改編自村上春樹短篇小說的日本電影Drive My Car，由西島秀俊、岡田將生主演，
台灣演員袁子芸也參演，更透露西島秀俊本人相當親切，還有許多暖男舉動。袁子芸曾參演戲劇「泡沫之夏」、「未來媽媽」，Drive My Car
是她的首部日本電影，飾演一名母語是中英雙語的女演員，在角色背景設定上與她自身有許多相似之處。袁子芸表示，開拍第一天自己很緊張，
而且第一場戲就與岡田將生有近距離接觸。不過當時午餐放飯時間延遲，拍戲時大家都有點餓，沒想到在最安靜的瞬間，岡田將生的肚子竟然咕嚕叫了一聲。
袁子芸回憶，當下兩人都很專業的繼續演出，等導演一喊卡之後，才忍不住大笑出來，連岡田將生都笑著表示不好意思。不過也因為這個意外插曲，
沖淡第一天拍攝的緊張和陌生感，瞬間拉近演員之間的距離。關於男主角西島秀俊，袁子芸看過許多他的作品，原以為他是比較有距離感的大明星，
沒想到西島秀俊在讀本過程就相當親切，還有許多暖男舉動。袁子芸分享，有天海外演員殺青後，相約要去慶祝，但因西島秀俊隔天一早還有拍攝，
無法同行，他便私下交代製片想請大家吃飯，麻煩製片先代為招待。近日電影傳出入圍坎城影展好消息，袁子芸也相當開心，她表示劇組群組簡直要暴動。
雖然她很希望能和劇組一起慶祝，卻因大家都分散不同地方，又正值疫情期間，只能透過通訊軟體互相道賀，期待Drive My Car 能在坎城影展奪下好成績。
由柏林影展銀熊獎得主、導演濱口龍介執導的Drive My Car，描述一名想尋找亡妻生前外遇對象的舞台劇演員，藉由與沉默寡言女司機的對話，
描繪出各自的故事與情感，電影8月20日將於日本上映。（編輯：張雅淨）1100627
"""

# %%
def wordExtractor(inputLIST):
    '''
    配合 Articut() 的 .getNounStemLIST() 和 .getVerbStemLIST() 拋棄位置資訊，只抽出詞彙。
    '''
    resultLIST = []
    for i in inputLIST: #在所有inputLIST裡面的小LIST 中
        if i == []:     #如果list是空的
            pass        #就忽略
        else:
            for e in i:                  #在小list裡面的元素
                resultLIST.append(e[-1]) #把內容存在resultLIST中
    return sorted(list(set(resultLIST))) #把所有的內容排序(sort)、放在list 裡面 (list)、用set排除重複的內容 (set)

# %%
#先使用 articut 斷詞，把結果存在newsResultDICT 裡面
username = "" #這裡填入您在 https://api.droidtown.co 使用的帳號 email。若使用空字串，則預設使用每小時 2000 字的公用額度。
apikey   = "" #這裡填入您在 https://api.droidtown.co 登入後取得的 api Key。若使用空字串，則預設使用每小時 2000 字的公用額度。

articut = Articut(username, apikey) 

newsResultDICT = articut.parse(newsinputSTR, userDefinedDictFILE="./mixedDICT.json")

#只要取用 "result_segmentation" 的結果，把結果存在seg_result
seg_result = newsResultDICT['result_segmentation']

#用 .split() 以 "/" 來分開，並存成 wordLIST 中
wordLIST = seg_result.split('/')

#使用Counter 來幫助你計算頻率
# 可以參考這個網站來看看 counter 怎麼用 https://www.itread01.com/articles/1476167108.html
from collections import Counter
c = Counter(wordLIST)

c.most_common()
print(c.most_common())
# Out:
# [('，', 38), ('的', 14), ('\n', 11), ('。', 11), (' ', 9), ('袁子芸', 7), ('將', 5), ('影展', 4), ('、', 4), ('電影', 4), ('Drive', 4), ('My', 4), ('Car', 4), ('西島秀俊', 4), ('岡田', 4), ('生', 4), ('許多', 4), ('她', 4), ('在', 4), ('與', 4), ('有', 4), ('都', 4), ('坎城', 3), ('日本', 3), ('演員', 3), ('也', 3), ('相當', 3), ('還有', 3), ('之', 3), ('是', 3), ('表示', 3), ('大家', 3), ('他', 3), ('能', 3), ('（', 2), ('）', 2), ('入圍', 2), ('自', 2), ('上', 2), ('由', 2), ('參', 2), ('演', 2), ('本', 2), ('人', 2), ('親切', 2), ('暖男', 2), ('舉動', 2), ('「', 2), ('」', 2), ('一名', 2), ('第', 2), ('一天', 2), ('很', 2), ('緊張', 2), ('就', 2), ('距離', 2), ('不過', 2), ('沒', 2), ('想到', 2), ('瞬間', 2), ('拍攝', 2), ('和', 2), ('慶祝', 2), ('因', 2), ('製片', 2), ('中央', 1), ('社', 1), ('記者', 1), ('葉冠吟', 1), ('台北', 1), ('27日', 1), ('電', 1), ('改編', 1), ('村', 1), ('春', 1), ('樹', 1), ('短', 1), ('篇小說', 1), ('主演', 1), ('台灣', 1), ('更', 1), ('透', 1), ('露西', 1), ('島秀', 1), ('俊', 1), ('曾', 1), ('戲劇', 1), ('泡沫', 1), ('夏', 1), ('未來', 1), ('媽媽', 1), ('首部', 1), ('飾演', 1), ('母語', 1), ('中', 1), ('英', 1), ('雙語', 1), ('女演員', 1), ('角色', 1), ('背景', 1), ('設定', 1), ('身', 1), ('相似', 1), ('處', 1), ('開拍', 1), ('自己', 1), ('而且', 1), ('第一場', 1), ('戲', 1), ('有近', 1), ('接觸', 1), ('當時', 1), ('午餐', 1), ('放', 1), ('飯時間', 1), ('延遲', 1), ('拍戲', 1), ('時', 1), ('點', 1), ('餓', 1), ('最安靜', 1), ('肚子', 1), ('竟然', 1), ('咕', 1), ('嚕', 1), ('叫了', 1), ('一聲', 1), ('回憶', 1), ('當下', 1), ('兩', 1), ('很專業', 1), ('繼續', 1), ('演出', 1), ('等', 1), ('導演', 1), ('一', 1), ('喊卡', 1), ('之後', 1), ('才', 1), ('忍不住', 1), ('大', 1), ('笑出來', 1), ('連', 1), ('笑著', 1), ('不好意思', 1), ('因為', 1), ('這個', 1), ('意外', 1), ('插曲', 1), ('沖淡', 1), ('陌生感', 1), ('拉近', 1), ('間', 1), ('關於', 1), ('男主角', 1), ('看過', 1), ('作品', 1), ('原', 1), ('以為', 1), ('比較', 1), ('距離感', 1), ('大明星', 1), ('讀', 1), ('過程', 1), ('分享', 1), ('天海', 1), ('外演員', 1), ('殺青', 1), ('後', 1), ('相約', 1), ('要去', 1), ('但', 1), ('隔天', 1), ('一早', 1), ('無法', 1), ('同行', 1), ('便', 1), ('私下', 1), ('交代', 1), ('想請', 1), ('吃飯', 1), ('麻煩', 1), ('先', 1), ('代為', 1), ('招待', 1), ('近日', 1), ('傳出', 1), ('好消息', 1), ('開心', 1), ('劇', 1), ('組群', 1), ('組', 1), ('簡直', 1), ('要', 1), ('暴動', 1), ('雖然', 1), ('希望', 1), ('劇組', 1), ('一起', 1), ('卻', 1), ('分散', 1), ('不同', 1), ('地方', 1), ('又', 1), ('正值', 1), ('疫情', 1), ('期間', 1), ('只', 1), ('透過', 1), ('通訊', 1), ('軟體', 1), ('互相', 1), ('道賀', 1), ('期待', 1), ('奪下', 1), ('好成績', 1), ('柏林', 1), ('銀熊', 1), ('獎得主', 1), ('導演濱口龍', 1), ('介', 1), ('執導', 1), ('描述', 1), ('想', 1), ('尋找', 1), ('亡妻生', 1), ('前', 1), ('外遇', 1), ('對', 1), ('象', 1), ('舞台劇', 1), ('藉由', 1), ('沉默寡言', 1), ('女司機', 1), ('對話', 1), ('描繪出', 1), ('各自', 1), ('故事', 1), ('情感', 1), ('8月', 1), ('20日', 1), ('於', 1), ('上映', 1), ('編輯', 1), ('：', 1), ('張雅淨', 1), ('1100627 ', 1)]

# %% [markdown]
# ## 課間練習3
# 可能你會說，我們可以把功能詞濾掉啊？然後再做TF-IDF 分析，這樣TF-IDF 會不會比較有意義呢？請和同學討論看看。

# %% [markdown]
# ## 課間練習4
#
# - 請使用籃球和棒球的文章來練習
# - articut.getLocationStemLIST() 和用 articut.getContentWordLIST() 和前面取名詞和動詞的方法是一樣的，請嘗試自己摸索使用看看。
# - 觀察看看 content word (內容詞) 和 location word (地方名稱) 是否具有比「動詞」或「名詞」更好/更差的特徵表現能力。說說看你的觀察。
# - 請直接使用之前的basketball 和 baseball 的resultDICT

# %%
#!/usr/bin/env python3
# -*- coding:utf-8 -*-

## 將棒球和籃球斷詞

from ArticutAPI import Articut
import json
from pprint import pprint


if __name__ == "__main__":
    
    username = "" #這裡填入您在 https://api.droidtown.co 使用的帳號 email。若使用空字串，則預設使用每小時 2000 字的公用額度。
    apikey   = "" #這裡填入您在 https://api.droidtown.co 登入後取得的 api Key。若使用空字串，則預設使用每小時 2000 字的公用額度。

    articut = Articut(username, apikey)    
    
    #以下語料可以參考
    baseballSTR = """本週三在紐約的比賽中，馬林魚此戰使用投手車輪戰，4名投手輪番上陣壓制大都會打線，
    前8局僅被敲出4支安打失1分，讓球隊能帶著2-1的領先優勢進入到9局下半。不過馬林魚推出巴斯登板關門，
    他面對首名打者麥尼爾，就被打出一發陽春砲，讓大都會追平比數，接下來又分別被敲出2支安打、投出保送，
    形成滿壘局面，此時輪到康福托上場打擊。在2好1壞的局面下，巴斯投了一顆內角滑球，康福托眼看這顆球越來越
    靠近自己的身體，似乎有下意識地將手伸進好球帶內，結果這球就直接碰觸到他的身肘，隨後主審庫爾帕判定這是
    一記觸身球，讓大都會兵不血刃拿下再見分，最終贏得比賽勝利。""".replace(" ", "")
    basketballSTR = """昨晚的紐約西區霸王之戰中，錯失勝利的太陽沒有就此束手就擒，延長賽一開始就打出7比2攻勢
    ，米契爾和康利雖然力圖追分，但太陽總能馬上回應。康利讀秒階段上籃得手，布克兩罰一中，再次留給爵士追平機會。
    米契爾造成犯規，可惜兩罰一中，保羅隨後用兩罰鎖定勝利。米契爾狂轟41分8籃板3助攻，本季單場得分次高；戈貝爾160
    分18籃板3抄截，波格丹諾維奇20分。康利拿到11分4助攻，克拉克森11分，兩人合計28投僅9中。爵士的三分攻勢難以
    有效施展，全場44投僅11中。""".replace(" ", "")
    
    #將 KNOWLEDGE_NBA_Teams.json 和 KNOWLEDGE_MLB_Teams.json 兩個體育欸字典讀取出來，合併成mixDICT 以後，寫入 mixedXICT.json 檔
    with open("ArticutAPI-master/Public_UserDefinedDict/KNOWLEDGE_NBA_Teams.json", encoding="utf-8") as f:
        nbaDICT = json.loads(f.read())
    with open("ArticutAPI-master/Public_UserDefinedDICT/KNOWLEDGE_MLB_Teams.json", encoding="utf-8") as f:
        mlbDICT = json.loads(f.read())
        
    mixedDICT = {**nbaDICT, **mlbDICT}
    with open("mixedDICT.json", mode = "w", encoding = "utf-8") as f:
        json.dump(mixedDICT, f, ensure_ascii=False)
    
    # 將baseballStR 和 basketballSTR 兩篇文本各自送入articut.parse() 裡，同時指定 userDefinedDictFILE 為剛才產生mixedDICT.json
    baseballResultDICT = articut.parse(baseballSTR, userDefinedDictFILE="./mixedDICT.json")
    basketballResultDICT = articut.parse(basketballSTR, userDefinedDictFILE="./mixedDICT.json")
    
    print("\n棒球斷詞結果：\n")
    pprint(baseballResultDICT)
    print("\n籃球斷詞結果：\n")
    pprint(basketballResultDICT)
# Out:
# 棒球斷詞結果：
#
# {'document': 'https://api.droidtown.co/document/',
#  'exec_time': 0.18035888671875,
#  'level': 'lv2',
#  'msg': 'Success!',
#  'product': 'https://api.droidtown.co/product/',
#  'result_obj': [[{'pos': 'FUNC_determiner', 'text': '本'},
#                  {'pos': 'TIME_week', 'text': '週三'},
#                  {'pos': 'FUNC_inner', 'text': '在'},
#                  {'pos': 'LOCATION', 'text': '紐約'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'ENTITY_nouny', 'text': '比賽'},
#                  {'pos': 'RANGE_locality', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'UserDefined', 'text': '馬林魚'},
#                  {'pos': 'ENTITY_nouny', 'text': '此戰'},
#                  {'pos': 'ACTION_verb', 'text': '使用'},
#                  {'pos': 'ENTITY_noun', 'text': '投手'},
#                  {'pos': 'ENTITY_nouny', 'text': '車輪戰'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_classifier', 'text': '4名'},
#                  {'pos': 'ENTITY_noun', 'text': '投手'},
#                  {'pos': 'MODIFIER', 'text': '輪番'},
#                  {'pos': 'ACTION_verb', 'text': '上陣'},
#                  {'pos': 'ACTION_verb', 'text': '壓制'},
#                  {'pos': 'UserDefined', 'text': '大都會'},
#                  {'pos': 'ENTITY_noun', 'text': '打線'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ENTITY_classifier', 'text': '前8局'},
#                  {'pos': 'MODIFIER', 'text': '僅'},
#                  {'pos': 'ACTION_lightVerb', 'text': '被'},
#                  {'pos': 'VerbP', 'text': '敲出'},
#                  {'pos': 'ENTITY_classifier', 'text': '4支'},
#                  {'pos': 'ENTITY_nouny', 'text': '安打'},
#                  {'pos': 'ACTION_verb', 'text': '失'},
#                  {'pos': 'ENTITY_measurement', 'text': '1分'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '讓'},
#                  {'pos': 'ENTITY_noun', 'text': '球隊'},
#                  {'pos': 'MODAL', 'text': '能'},
#                  {'pos': 'VerbP', 'text': '帶著'},
#                  {'pos': 'ENTITY_num', 'text': '2'}],
#                 [{'pos': 'PUNCTUATION', 'text': '-'}],
#                 [{'pos': 'ENTITY_num', 'text': '1'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'ENTITY_nouny', 'text': '領先'},
#                  {'pos': 'ENTITY_nouny', 'text': '優勢'},
#                  {'pos': 'ACTION_verb', 'text': '進入'},
#                  {'pos': 'ACTION_verb', 'text': '到'},
#                  {'pos': 'ENTITY_classifier', 'text': '9局'},
#                  {'pos': 'RANGE_locality', 'text': '下半'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'FUNC_inner', 'text': '不過'},
#                  {'pos': 'UserDefined', 'text': '馬林魚'},
#                  {'pos': 'ACTION_verb', 'text': '推出'},
#                  {'pos': 'ENTITY_person', 'text': '巴斯'},
#                  {'pos': 'ENTITY_nouny', 'text': '登板'},
#                  {'pos': 'VerbP', 'text': '關門'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ENTITY_pronoun', 'text': '他'},
#                  {'pos': 'ACTION_verb', 'text': '面對'},
#                  {'pos': 'ENTITY_classifier', 'text': '首名'},
#                  {'pos': 'ENTITY_noun', 'text': '打者'},
#                  {'pos': 'ENTITY_person', 'text': '麥尼爾'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'FUNC_inner', 'text': '就'},
#                  {'pos': 'ACTION_lightVerb', 'text': '被'},
#                  {'pos': 'ACTION_verb', 'text': '打出'},
#                  {'pos': 'ENTITY_classifier', 'text': '一發'},
#                  {'pos': 'ENTITY_nouny', 'text': '陽春砲'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '讓'},
#                  {'pos': 'UserDefined', 'text': '大都會'},
#                  {'pos': 'ENTITY_nouny', 'text': '追平比數'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '接下來'},
#                  {'pos': 'FUNC_inner', 'text': '又'},
#                  {'pos': 'MODIFIER', 'text': '分別'},
#                  {'pos': 'ACTION_lightVerb', 'text': '被'},
#                  {'pos': 'VerbP', 'text': '敲出'},
#                  {'pos': 'ENTITY_classifier', 'text': '2支'},
#                  {'pos': 'ENTITY_nouny', 'text': '安打'}],
#                 [{'pos': 'PUNCTUATION', 'text': '、'}],
#                 [{'pos': 'ACTION_verb', 'text': '投出'},
#                  {'pos': 'ACTION_verb', 'text': '保送'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ACTION_verb', 'text': '形成'},
#                  {'pos': 'ENTITY_noun', 'text': '滿壘'},
#                  {'pos': 'ENTITY_nounHead', 'text': '局面'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'FUNC_determiner', 'text': '此'},
#                  {'pos': 'FUNC_inner', 'text': '時'},
#                  {'pos': 'ACTION_verb', 'text': '輪到'},
#                  {'pos': 'ENTITY_person', 'text': '康福托'},
#                  {'pos': 'ACTION_verb', 'text': '上場'},
#                  {'pos': 'ACTION_verb', 'text': '打擊'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'FUNC_inner', 'text': '在'},
#                  {'pos': 'ENTITY_num', 'text': '2'},
#                  {'pos': 'FUNC_degreeHead', 'text': '好'},
#                  {'pos': 'ENTITY_num', 'text': '1'},
#                  {'pos': 'MODIFIER', 'text': '壞'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'ENTITY_nouny', 'text': '局面'},
#                  {'pos': 'RANGE_locality', 'text': '下'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_person', 'text': '巴斯'},
#                  {'pos': 'VerbP', 'text': '投了'},
#                  {'pos': 'ENTITY_classifier', 'text': '一顆'},
#                  {'pos': 'RANGE_locality', 'text': '內'},
#                  {'pos': 'ENTITY_oov', 'text': '角滑球'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_person', 'text': '康福托'},
#                  {'pos': 'ENTITY_nouny', 'text': '眼'},
#                  {'pos': 'ACTION_verb', 'text': '看'},
#                  {'pos': 'ENTITY_DetPhrase', 'text': '這顆'},
#                  {'pos': 'ENTITY_nouny', 'text': '球'},
#                  {'pos': 'ACTION_verb', 'text': '越來'},
#                  {'pos': 'MODIFIER', 'text': '越'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ACTION_verb', 'text': '靠近'},
#                  {'pos': 'ENTITY_pronoun', 'text': '自己'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'ENTITY_noun', 'text': '身體'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'MODIFIER', 'text': '似乎'},
#                  {'pos': 'ACTION_verb', 'text': '有下'},
#                  {'pos': 'ENTITY_nouny', 'text': '意識地'},
#                  {'pos': 'MODAL', 'text': '將'},
#                  {'pos': 'ENTITY_oov', 'text': '手'},
#                  {'pos': 'ACTION_verb', 'text': '伸進'},
#                  {'pos': 'FUNC_degreeHead', 'text': '好'},
#                  {'pos': 'LOCATION', 'text': '球帶內'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'FUNC_inter', 'text': '結果'},
#                  {'pos': 'ENTITY_nouny', 'text': '這球'},
#                  {'pos': 'FUNC_inner', 'text': '就'},
#                  {'pos': 'MODIFIER', 'text': '直接'},
#                  {'pos': 'ACTION_verb', 'text': '碰觸'},
#                  {'pos': 'ACTION_verb', 'text': '到'},
#                  {'pos': 'ENTITY_pronoun', 'text': '他'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'ENTITY_nouny', 'text': '身肘'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '隨'},
#                  {'pos': 'RANGE_period', 'text': '後'},
#                  {'pos': 'ENTITY_nouny', 'text': '主審'},
#                  {'pos': 'ENTITY_person', 'text': '庫爾帕'},
#                  {'pos': 'ACTION_verb', 'text': '判定'},
#                  {'pos': 'FUNC_determiner', 'text': '這'},
#                  {'pos': 'AUX', 'text': '是'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ENTITY_classifier', 'text': '一記'},
#                  {'pos': 'ENTITY_noun', 'text': '觸身球'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '讓'},
#                  {'pos': 'UserDefined', 'text': '大都會'},
#                  {'pos': 'IDIOM', 'text': '兵不血刃'},
#                  {'pos': 'ACTION_verb', 'text': '拿下'},
#                  {'pos': 'ACTION_verb', 'text': '再見'},
#                  {'pos': 'ENTITY_nouny', 'text': '分'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'DegreeP', 'text': '最終'},
#                  {'pos': 'ACTION_verb', 'text': '贏得'},
#                  {'pos': 'ENTITY_nouny', 'text': '比賽'},
#                  {'pos': 'ENTITY_nouny', 'text': '勝利'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}]],
#  'result_pos': ['<FUNC_determiner>本</FUNC_determiner><TIME_week>週三</TIME_week><FUNC_inner>在</FUNC_inner><LOCATION>紐約</LOCATION><FUNC_inner>的</FUNC_inner><ENTITY_nouny>比賽</ENTITY_nouny><RANGE_locality>中</RANGE_locality>',
#                 '，',
#                 '<UserDefined>馬林魚</UserDefined><ENTITY_nouny>此戰</ENTITY_nouny><ACTION_verb>使用</ACTION_verb><ENTITY_noun>投手</ENTITY_noun><ENTITY_nouny>車輪戰</ENTITY_nouny>',
#                 '，',
#                 '<ENTITY_classifier>4名</ENTITY_classifier><ENTITY_noun>投手</ENTITY_noun><MODIFIER>輪番</MODIFIER><ACTION_verb>上陣</ACTION_verb><ACTION_verb>壓制</ACTION_verb><UserDefined>大都會</UserDefined><ENTITY_noun>打線</ENTITY_noun>',
#                 '，',
#                 '\n',
#                 '<ENTITY_classifier>前8局</ENTITY_classifier><MODIFIER>僅</MODIFIER><ACTION_lightVerb>被</ACTION_lightVerb><VerbP>敲出</VerbP><ENTITY_classifier>4支</ENTITY_classifier><ENTITY_nouny>安打</ENTITY_nouny><ACTION_verb>失</ACTION_verb><ENTITY_measurement>1分</ENTITY_measurement>',
#                 '，',
#                 '<ACTION_verb>讓</ACTION_verb><ENTITY_noun>球隊</ENTITY_noun><MODAL>能</MODAL><VerbP>帶著</VerbP><ENTITY_num>2</ENTITY_num>',
#                 '-',
#                 '<ENTITY_num>1</ENTITY_num><FUNC_inner>的</FUNC_inner><ENTITY_nouny>領先</ENTITY_nouny><ENTITY_nouny>優勢</ENTITY_nouny><ACTION_verb>進入</ACTION_verb><ACTION_verb>到</ACTION_verb><ENTITY_classifier>9局</ENTITY_classifier><RANGE_locality>下半</RANGE_locality>',
#                 '。',
#                 '<FUNC_inner>不過</FUNC_inner><UserDefined>馬林魚</UserDefined><ACTION_verb>推出</ACTION_verb><ENTITY_person>巴斯</ENTITY_person><ENTITY_nouny>登板</ENTITY_nouny><VerbP>關門</VerbP>',
#                 '，',
#                 '\n',
#                 '<ENTITY_pronoun>他</ENTITY_pronoun><ACTION_verb>面對</ACTION_verb><ENTITY_classifier>首名</ENTITY_classifier><ENTITY_noun>打者</ENTITY_noun><ENTITY_person>麥尼爾</ENTITY_person>',
#                 '，',
#                 '<FUNC_inner>就</FUNC_inner><ACTION_lightVerb>被</ACTION_lightVerb><ACTION_verb>打出</ACTION_verb><ENTITY_classifier>一發</ENTITY_classifier><ENTITY_nouny>陽春砲</ENTITY_nouny>',
#                 '，',
#                 '<ACTION_verb>讓</ACTION_verb><UserDefined>大都會</UserDefined><ENTITY_nouny>追平比數</ENTITY_nouny>',
#                 '，',
#                 '<ACTION_verb>接下來</ACTION_verb><FUNC_inner>又</FUNC_inner><MODIFIER>分別</MODIFIER><ACTION_lightVerb>被</ACTION_lightVerb><VerbP>敲出</VerbP><ENTITY_classifier>2支</ENTITY_classifier><ENTITY_nouny>安打</ENTITY_nouny>',
#                 '、',
#                 '<ACTION_verb>投出</ACTION_verb><ACTION_verb>保送</ACTION_verb>',
#                 '，',
#                 '\n',
#                 '<ACTION_verb>形成</ACTION_verb><ENTITY_noun>滿壘</ENTITY_noun><ENTITY_nounHead>局面</ENTITY_nounHead>',
#                 '，',
#                 '<FUNC_determiner>此</FUNC_determiner><FUNC_inner>時</FUNC_inner><ACTION_verb>輪到</ACTION_verb><ENTITY_person>康福托</ENTITY_person><ACTION_verb>上場</ACTION_verb><ACTION_verb>打擊</ACTION_verb>',
#                 '。',
#                 '<FUNC_inner>在</FUNC_inner><ENTITY_num>2</ENTITY_num><FUNC_degreeHead>好</FUNC_degreeHead><ENTITY_num>1</ENTITY_num><MODIFIER>壞</MODIFIER><FUNC_inner>的</FUNC_inner><ENTITY_nouny>局面</ENTITY_nouny><RANGE_locality>下</RANGE_locality>',
#                 '，',
#                 '<ENTITY_person>巴斯</ENTITY_person><VerbP>投了</VerbP><ENTITY_classifier>一顆</ENTITY_classifier><RANGE_locality>內</RANGE_locality><ENTITY_oov>角滑球</ENTITY_oov>',
#                 '，',
#                 '<ENTITY_person>康福托</ENTITY_person><ENTITY_nouny>眼</ENTITY_nouny><ACTION_verb>看</ACTION_verb><ENTITY_DetPhrase>這顆</ENTITY_DetPhrase><ENTITY_nouny>球</ENTITY_nouny><ACTION_verb>越來</ACTION_verb><MODIFIER>越</MODIFIER>',
#                 '\n',
#                 '<ACTION_verb>靠近</ACTION_verb><ENTITY_pronoun>自己</ENTITY_pronoun><FUNC_inner>的</FUNC_inner><ENTITY_noun>身體</ENTITY_noun>',
#                 '，',
#                 '<MODIFIER>似乎</MODIFIER><ACTION_verb>有下</ACTION_verb><ENTITY_nouny>意識地</ENTITY_nouny><MODAL>將</MODAL><ENTITY_oov>手</ENTITY_oov><ACTION_verb>伸進</ACTION_verb><FUNC_degreeHead>好</FUNC_degreeHead><LOCATION>球帶內</LOCATION>',
#                 '，',
#                 '<FUNC_inter>結果</FUNC_inter><ENTITY_nouny>這球</ENTITY_nouny><FUNC_inner>就</FUNC_inner><MODIFIER>直接</MODIFIER><ACTION_verb>碰觸</ACTION_verb><ACTION_verb>到</ACTION_verb><ENTITY_pronoun>他</ENTITY_pronoun><FUNC_inner>的</FUNC_inner><ENTITY_nouny>身肘</ENTITY_nouny>',
#                 '，',
#                 '<ACTION_verb>隨</ACTION_verb><RANGE_period>後</RANGE_period><ENTITY_nouny>主審</ENTITY_nouny><ENTITY_person>庫爾帕</ENTITY_person><ACTION_verb>判定</ACTION_verb><FUNC_determiner>這</FUNC_determiner><AUX>是</AUX>',
#                 '\n',
#                 '<ENTITY_classifier>一記</ENTITY_classifier><ENTITY_noun>觸身球</ENTITY_noun>',
#                 '，',
#                 '<ACTION_verb>讓</ACTION_verb><UserDefined>大都會</UserDefined><IDIOM>兵不血刃</IDIOM><ACTION_verb>拿下</ACTION_verb><ACTION_verb>再見</ACTION_verb><ENTITY_nouny>分</ENTITY_nouny>',
#                 '，',
#                 '<DegreeP>最終</DegreeP><ACTION_verb>贏得</ACTION_verb><ENTITY_nouny>比賽</ENTITY_nouny><ENTITY_nouny>勝利</ENTITY_nouny>',
#                 '。'],
#  'result_segmentation': '本/週三/在/紐約/的/比賽/中/，/馬林魚/此戰/使用/投手/車輪戰/，/4名/投手/輪番/上陣/壓制/大都會/打線/，/\n'
#                         '/前8局/僅/被/敲出/4支/安打/失/1分/，/讓/球隊/能/帶著/2/-/1/的/領先/優勢/進入/到/9局/下半/。/不過/馬林魚/推出/巴斯/登板/關門/，/\n'
#                         '/他/面對/首名/打者/麥尼爾/，/就/被/打出/一發/陽春砲/，/讓/大都會/追平比數/，/接下來/又/分別/被/敲出/2支/安打/、/投出/保送/，/\n'
#                         '/形成/滿壘/局面/，/此/時/輪到/康福托/上場/打擊/。/在/2/好/1/壞/的/局面/下/，/巴斯/投了/一顆/內/角滑球/，/康福托/眼/看/這顆/球/越來/越/\n'
#                         '/靠近/自己/的/身體/，/似乎/有下/意識地/將/手/伸進/好/球帶內/，/結果/這球/就/直接/碰觸/到/他/的/身肘/，/隨/後/主審/庫爾帕/判定/這/是/\n'
#                         '/一記/觸身球/，/讓/大都會/兵不血刃/拿下/再見/分/，/最終/贏得/比賽/勝利/。',
#  'status': True,
#  'version': 'v236',
#  'word_count_balance': 100000}
#
# 籃球斷詞結果：
#
# {'document': 'https://api.droidtown.co/document/',
#  'exec_time': 0.7714593410491943,
#  'level': 'lv2',
#  'msg': 'Success!',
#  'product': 'https://api.droidtown.co/product/',
#  'result_obj': [[{'pos': 'TIME_day', 'text': '昨晚'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'LOCATION', 'text': '紐約'},
#                  {'pos': 'LOCATION', 'text': '西區'},
#                  {'pos': 'ENTITY_oov', 'text': '霸王'},
#                  {'pos': 'FUNC_inner', 'text': '之'},
#                  {'pos': 'ENTITY_nouny', 'text': '戰'},
#                  {'pos': 'RANGE_locality', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ACTION_verb', 'text': '錯失'},
#                  {'pos': 'ENTITY_nouny', 'text': '勝利'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'UserDefined', 'text': '太陽'},
#                  {'pos': 'FUNC_negation', 'text': '沒有'},
#                  {'pos': 'FUNC_inner', 'text': '就'},
#                  {'pos': 'FUNC_determiner', 'text': '此'},
#                  {'pos': 'IDIOM', 'text': '束手就擒'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_noun', 'text': '延長賽'},
#                  {'pos': 'ENTITY_num', 'text': '一'},
#                  {'pos': 'ACTION_verb', 'text': '開始'},
#                  {'pos': 'FUNC_inner', 'text': '就'},
#                  {'pos': 'ACTION_verb', 'text': '打出'},
#                  {'pos': 'ENTITY_num', 'text': '7'},
#                  {'pos': 'ACTION_verb', 'text': '比'},
#                  {'pos': 'ENTITY_num', 'text': '2'},
#                  {'pos': 'ENTITY_oov', 'text': '攻勢'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_person', 'text': '米契爾'},
#                  {'pos': 'FUNC_conjunction', 'text': '和'},
#                  {'pos': 'ENTITY_person', 'text': '康利'},
#                  {'pos': 'FUNC_inter', 'text': '雖然'},
#                  {'pos': 'ACTION_verb', 'text': '力圖'},
#                  {'pos': 'ACTION_verb', 'text': '追分'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'FUNC_inter', 'text': '但'},
#                  {'pos': 'UserDefined', 'text': '太陽'},
#                  {'pos': 'MODIFIER', 'text': '總'},
#                  {'pos': 'MODAL', 'text': '能'},
#                  {'pos': 'TIME_justtime', 'text': '馬上'},
#                  {'pos': 'ACTION_verb', 'text': '回應'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'ENTITY_person', 'text': '康利'},
#                  {'pos': 'ACTION_verb', 'text': '讀秒'},
#                  {'pos': 'ENTITY_noun', 'text': '階段'},
#                  {'pos': 'ACTION_verb', 'text': '上籃'},
#                  {'pos': 'ACTION_verb', 'text': '得手'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_oov', 'text': '布克'},
#                  {'pos': 'ENTITY_num', 'text': '兩'},
#                  {'pos': 'ACTION_verb', 'text': '罰'},
#                  {'pos': 'ENTITY_num', 'text': '一'},
#                  {'pos': 'ENTITY_oov', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'MODIFIER', 'text': '再次'},
#                  {'pos': 'ACTION_verb', 'text': '留給'},
#                  {'pos': 'UserDefined', 'text': '爵士'},
#                  {'pos': 'ACTION_verb', 'text': '追平'},
#                  {'pos': 'ENTITY_noun', 'text': '機會'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ENTITY_person', 'text': '米契爾'},
#                  {'pos': 'ACTION_verb', 'text': '造成'},
#                  {'pos': 'ACTION_verb', 'text': '犯規'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'MODIFIER', 'text': '可惜'},
#                  {'pos': 'ENTITY_num', 'text': '兩'},
#                  {'pos': 'ACTION_verb', 'text': '罰'},
#                  {'pos': 'ENTITY_num', 'text': '一'},
#                  {'pos': 'ENTITY_oov', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_person', 'text': '保羅'},
#                  {'pos': 'ACTION_verb', 'text': '隨'},
#                  {'pos': 'RANGE_period', 'text': '後'},
#                  {'pos': 'ACTION_verb', 'text': '用'},
#                  {'pos': 'ENTITY_num', 'text': '兩'},
#                  {'pos': 'ACTION_verb', 'text': '罰'},
#                  {'pos': 'ACTION_verb', 'text': '鎖定'},
#                  {'pos': 'ENTITY_nouny', 'text': '勝利'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'ENTITY_person', 'text': '米契爾'},
#                  {'pos': 'ACTION_verb', 'text': '狂轟'},
#                  {'pos': 'ENTITY_measurement', 'text': '41分'},
#                  {'pos': 'ENTITY_num', 'text': '8'},
#                  {'pos': 'ENTITY_oov', 'text': '籃板'},
#                  {'pos': 'ENTITY_num', 'text': '3'},
#                  {'pos': 'ACTION_verb', 'text': '助攻'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'FUNC_determiner', 'text': '本'},
#                  {'pos': 'TIME_season', 'text': '季'},
#                  {'pos': 'ENTITY_nounHead', 'text': '單場'},
#                  {'pos': 'ACTION_verb', 'text': '得分'},
#                  {'pos': 'ENTITY_nouny', 'text': '次'},
#                  {'pos': 'MODIFIER', 'text': '高'}],
#                 [{'pos': 'PUNCTUATION', 'text': '；'}],
#                 [{'pos': 'ENTITY_person', 'text': '戈貝爾'},
#                  {'pos': 'ENTITY_num', 'text': '160'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'ACTION_verb', 'text': '分'},
#                  {'pos': 'ENTITY_num', 'text': '18'},
#                  {'pos': 'ENTITY_oov', 'text': '籃板'},
#                  {'pos': 'ENTITY_num', 'text': '3'},
#                  {'pos': 'ACTION_verb', 'text': '抄截'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_oov', 'text': '波格丹諾維奇'},
#                  {'pos': 'TIME_justtime', 'text': '20分'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'ENTITY_person', 'text': '康利'},
#                  {'pos': 'ACTION_verb', 'text': '拿到'},
#                  {'pos': 'TIME_justtime', 'text': '11分'},
#                  {'pos': 'ENTITY_num', 'text': '4'},
#                  {'pos': 'ACTION_verb', 'text': '助攻'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_person', 'text': '克拉克森'},
#                  {'pos': 'TIME_justtime', 'text': '11分'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'ENTITY_num', 'text': '兩'},
#                  {'pos': 'ENTITY_noun', 'text': '人'},
#                  {'pos': 'ACTION_verb', 'text': '合計'},
#                  {'pos': 'ENTITY_num', 'text': '28'},
#                  {'pos': 'ACTION_verb', 'text': '投'},
#                  {'pos': 'MODIFIER', 'text': '僅'},
#                  {'pos': 'ENTITY_num', 'text': '9'},
#                  {'pos': 'RANGE_locality', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}],
#                 [{'pos': 'UserDefined', 'text': '爵士'},
#                  {'pos': 'FUNC_inner', 'text': '的'},
#                  {'pos': 'TIME_justtime', 'text': '三分'},
#                  {'pos': 'ENTITY_oov', 'text': '攻勢'},
#                  {'pos': 'MODIFIER', 'text': '難'},
#                  {'pos': 'FUNC_inner', 'text': '以'}],
#                 [{'pos': 'PUNCTUATION', 'text': '\n'}],
#                 [{'pos': 'MODIFIER', 'text': '有效'},
#                  {'pos': 'ACTION_verb', 'text': '施展'}],
#                 [{'pos': 'PUNCTUATION', 'text': '，'}],
#                 [{'pos': 'QUANTIFIER', 'text': '全'},
#                  {'pos': 'ENTITY_noun', 'text': '場'},
#                  {'pos': 'ENTITY_num', 'text': '44'},
#                  {'pos': 'ACTION_verb', 'text': '投'},
#                  {'pos': 'MODIFIER', 'text': '僅'},
#                  {'pos': 'ENTITY_num', 'text': '11'},
#                  {'pos': 'RANGE_locality', 'text': '中'}],
#                 [{'pos': 'PUNCTUATION', 'text': '。'}]],
#  'result_pos': ['<TIME_day>昨晚</TIME_day><FUNC_inner>的</FUNC_inner><LOCATION>紐約</LOCATION><LOCATION>西區</LOCATION><ENTITY_oov>霸王</ENTITY_oov><FUNC_inner>之</FUNC_inner><ENTITY_nouny>戰</ENTITY_nouny><RANGE_locality>中</RANGE_locality>',
#                 '，',
#                 '<ACTION_verb>錯失</ACTION_verb><ENTITY_nouny>勝利</ENTITY_nouny><FUNC_inner>的</FUNC_inner><UserDefined>太陽</UserDefined><FUNC_negation>沒有</FUNC_negation><FUNC_inner>就</FUNC_inner><FUNC_determiner>此</FUNC_determiner><IDIOM>束手就擒</IDIOM>',
#                 '，',
#                 '<ENTITY_noun>延長賽</ENTITY_noun><ENTITY_num>一</ENTITY_num><ACTION_verb>開始</ACTION_verb><FUNC_inner>就</FUNC_inner><ACTION_verb>打出</ACTION_verb><ENTITY_num>7</ENTITY_num><ACTION_verb>比</ACTION_verb><ENTITY_num>2</ENTITY_num><ENTITY_oov>攻勢</ENTITY_oov>',
#                 '\n',
#                 '，',
#                 '<ENTITY_person>米契爾</ENTITY_person><FUNC_conjunction>和</FUNC_conjunction><ENTITY_person>康利</ENTITY_person><FUNC_inter>雖然</FUNC_inter><ACTION_verb>力圖</ACTION_verb><ACTION_verb>追分</ACTION_verb>',
#                 '，',
#                 '<FUNC_inter>但</FUNC_inter><UserDefined>太陽</UserDefined><MODIFIER>總</MODIFIER><MODAL>能</MODAL><TIME_justtime>馬上</TIME_justtime><ACTION_verb>回應</ACTION_verb>',
#                 '。',
#                 '<ENTITY_person>康利</ENTITY_person><ACTION_verb>讀秒</ACTION_verb><ENTITY_noun>階段</ENTITY_noun><ACTION_verb>上籃</ACTION_verb><ACTION_verb>得手</ACTION_verb>',
#                 '，',
#                 '<ENTITY_oov>布克</ENTITY_oov><ENTITY_num>兩</ENTITY_num><ACTION_verb>罰</ACTION_verb><ENTITY_num>一</ENTITY_num><ENTITY_oov>中</ENTITY_oov>',
#                 '，',
#                 '<MODIFIER>再次</MODIFIER><ACTION_verb>留給</ACTION_verb><UserDefined>爵士</UserDefined><ACTION_verb>追平</ACTION_verb><ENTITY_noun>機會</ENTITY_noun>',
#                 '。',
#                 '\n',
#                 '<ENTITY_person>米契爾</ENTITY_person><ACTION_verb>造成</ACTION_verb><ACTION_verb>犯規</ACTION_verb>',
#                 '，',
#                 '<MODIFIER>可惜</MODIFIER><ENTITY_num>兩</ENTITY_num><ACTION_verb>罰</ACTION_verb><ENTITY_num>一</ENTITY_num><ENTITY_oov>中</ENTITY_oov>',
#                 '，',
#                 '<ENTITY_person>保羅</ENTITY_person><ACTION_verb>隨</ACTION_verb><RANGE_period>後</RANGE_period><ACTION_verb>用</ACTION_verb><ENTITY_num>兩</ENTITY_num><ACTION_verb>罰</ACTION_verb><ACTION_verb>鎖定</ACTION_verb><ENTITY_nouny>勝利</ENTITY_nouny>',
#                 '。',
#                 '<ENTITY_person>米契爾</ENTITY_person><ACTION_verb>狂轟</ACTION_verb><ENTITY_measurement>41分</ENTITY_measurement><ENTITY_num>8</ENTITY_num><ENTITY_oov>籃板</ENTITY_oov><ENTITY_num>3</ENTITY_num><ACTION_verb>助攻</ACTION_verb>',
#                 '，',
#                 '<FUNC_determiner>本</FUNC_determiner><TIME_season>季</TIME_season><ENTITY_nounHead>單場</ENTITY_nounHead><ACTION_verb>得分</ACTION_verb><ENTITY_nouny>次</ENTITY_nouny><MODIFIER>高</MODIFIER>',
#                 '；',
#                 '<ENTITY_person>戈貝爾</ENTITY_person><ENTITY_num>160</ENTITY_num>',
#                 '\n',
#                 '<ACTION_verb>分</ACTION_verb><ENTITY_num>18</ENTITY_num><ENTITY_oov>籃板</ENTITY_oov><ENTITY_num>3</ENTITY_num><ACTION_verb>抄截</ACTION_verb>',
#                 '，',
#                 '<ENTITY_oov>波格丹諾維奇</ENTITY_oov><TIME_justtime>20分</TIME_justtime>',
#                 '。',
#                 '<ENTITY_person>康利</ENTITY_person><ACTION_verb>拿到</ACTION_verb><TIME_justtime>11分</TIME_justtime><ENTITY_num>4</ENTITY_num><ACTION_verb>助攻</ACTION_verb>',
#                 '，',
#                 '<ENTITY_person>克拉克森</ENTITY_person><TIME_justtime>11分</TIME_justtime>',
#                 '，',
#                 '<ENTITY_num>兩</ENTITY_num><ENTITY_noun>人</ENTITY_noun><ACTION_verb>合計</ACTION_verb><ENTITY_num>28</ENTITY_num><ACTION_verb>投</ACTION_verb><MODIFIER>僅</MODIFIER><ENTITY_num>9</ENTITY_num><RANGE_locality>中</RANGE_locality>',
#                 '。',
#                 '<UserDefined>爵士</UserDefined><FUNC_inner>的</FUNC_inner><TIME_justtime>三分</TIME_justtime><ENTITY_oov>攻勢</ENTITY_oov><MODIFIER>難</MODIFIER><FUNC_inner>以</FUNC_inner>',
#                 '\n',
#                 '<MODIFIER>有效</MODIFIER><ACTION_verb>施展</ACTION_verb>',
#                 '，',
#                 '<QUANTIFIER>全</QUANTIFIER><ENTITY_noun>場</ENTITY_noun><ENTITY_num>44</ENTITY_num><ACTION_verb>投</ACTION_verb><MODIFIER>僅</MODIFIER><ENTITY_num>11</ENTITY_num><RANGE_locality>中</RANGE_locality>',
#                 '。'],
#  'result_segmentation': '昨晚/的/紐約/西區/霸王/之/戰/中/，/錯失/勝利/的/太陽/沒有/就/此/束手就擒/，/延長賽/一/開始/就/打出/7/比/2/攻勢/\n'
#                         '/，/米契爾/和/康利/雖然/力圖/追分/，/但/太陽/總/能/馬上/回應/。/康利/讀秒/階段/上籃/得手/，/布克/兩/罰/一/中/，/再次/留給/爵士/追平/機會/。/\n'
#                         '/米契爾/造成/犯規/，/可惜/兩/罰/一/中/，/保羅/隨/後/用/兩/罰/鎖定/勝利/。/米契爾/狂轟/41分/8/籃板/3/助攻/，/本/季/單場/得分/次/高/；/戈貝爾/160/\n'
#                         '/分/18/籃板/3/抄截/，/波格丹諾維奇/20分/。/康利/拿到/11分/4/助攻/，/克拉克森/11分/，/兩/人/合計/28/投/僅/9/中/。/爵士/的/三分/攻勢/難/以/\n'
#                         '/有效/施展/，/全/場/44/投/僅/11/中/。',
#  'status': True,
#  'version': 'v236',
#  'word_count_balance': 100000}

# %%
## 用articut.getContentWordLIST() 
baseballContentLIST = articut.getContentWordLIST(baseballResultDICT) 
print("\n getContentWordList 棒球結果")
print(wordExtractor(baseballContentLIST))

basketballContentLIST = articut.getContentWordLIST(basketballResultDICT)
print("\n getContentWordList 籃球結果")
print(wordExtractor(basketballContentLIST))

## 用 articut.getLocationStemLIST()
baseballLocationLIST = articut.getLocationStemLIST(baseballResultDICT) 
print("\n getLocationStemLIST 棒球結果")
print(wordExtractor(baseballLocationLIST))

basketballLocationLIST = articut.getLocationStemLIST(basketballResultDICT)
print("\n getLocationStemLIST 籃球結果")
print(wordExtractor(basketballLocationLIST))

## 用 articut.getNounStemLIST()
baseballNounLIST = articut.getNounStemLIST(baseballResultDICT) 
print("\n getNounStemLIST 棒球結果")
print(wordExtractor(baseballNounLIST))

basketballNounLIST = articut.getNounStemLIST(basketballResultDICT)
print("\n getNounStemLIST 籃球結果")
print(wordExtractor(basketballNounLIST))

## articut.getVerbStemLIST() 
baseballVerbLIST = articut.getVerbStemLIST(baseballResultDICT) 
print("\n getVerbStemLIST 棒球結果")
print(wordExtractor(baseballVerbLIST))

basketballVerbLIST = articut.getVerbStemLIST(basketballResultDICT)
print("\n getVerbStemLIST 籃球結果")
print(wordExtractor(basketballVerbLIST))
# Out:
#  getContentWordList 棒球結果
# ['上場', '上陣', '主審', '伸進', '似乎', '使用', '保送', '僅', '優勢', '再見', '分', '分別', '判定', '到', '勝利', '壓制', '壞', '大都會', '失', '安打', '局面', '帶', '形成', '意識地', '手', '打出', '打擊', '打線', '打者', '投', '投出', '投手', '拿下', '接下來', '推出', '敲', '最終', '有下', '此戰', '比賽', '滿壘', '球', '球隊', '登板', '直接', '看', '眼', '碰觸', '角滑球', '觸身球', '讓', '贏得', '越', '越來', '身肘', '身體', '車輪戰', '輪到', '輪番', '追平比數', '這球', '進入', '關', '陽春砲', '隨', '靠近', '面對', '領先', '馬林魚']
#
#  getContentWordList 籃球結果
# ['上籃', '中', '人', '僅', '再次', '分', '力圖', '助攻', '勝利', '可惜', '合計', '單場', '回應', '場', '太陽', '布克', '延長賽', '得分', '得手', '戰', '打出', '抄截', '投', '拿到', '攻勢', '施展', '有效', '機會', '次', '比', '波格丹諾維奇', '爵士', '犯規', '狂轟', '用', '留給', '籃板', '總', '罰', '讀秒', '追分', '追平', '造成', '錯失', '鎖定', '開始', '階段', '隨', '難', '霸王', '高']
#
#  getLocationStemLIST 棒球結果
# ['球帶內', '紐約']
#
#  getLocationStemLIST 籃球結果
# ['紐約', '西區']
#
#  getNounStemLIST 棒球結果
# ['主審', '優勢', '分', '勝利', '安打', '局面', '意識地', '手', '打線', '打者', '投手', '此戰', '比賽', '滿壘', '球', '球隊', '登板', '眼', '角滑球', '觸身球', '身肘', '身體', '車輪戰', '追平比數', '這球', '陽春砲', '領先']
#
#  getNounStemLIST 籃球結果
# ['中', '人', '勝利', '單場', '場', '布克', '延長賽', '戰', '攻勢', '機會', '次', '波格丹諾維奇', '籃板', '階段', '霸王']
#
#  getVerbStemLIST 棒球結果
# ['上場', '上陣', '伸進', '使用', '保送', '再見', '判定', '到', '壓制', '失', '帶', '形成', '打出', '打擊', '投', '投出', '拿下', '接下來', '推出', '敲', '有下', '看', '碰觸', '讓', '贏得', '越來', '輪到', '進入', '關', '隨', '靠近', '面對']
#
#  getVerbStemLIST 籃球結果
# ['上籃', '分', '力圖', '助攻', '合計', '回應', '得分', '得手', '打出', '抄截', '投', '拿到', '施展', '比', '犯規', '狂轟', '用', '留給', '罰', '讀秒', '追分', '追平', '造成', '錯失', '鎖定', '開始', '隨']

# %% [markdown]
# 以上是這些不同函式的結果，請大家觀察看看 content word (內容詞) 和 location word (地方名稱) 是否具有比「動詞」或「名詞」更好/更差的特徵表現能力。說說看你的觀察。
